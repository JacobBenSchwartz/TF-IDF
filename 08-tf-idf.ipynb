# %% [markdown]
# ---
# title: "TF-IDF, with a recap of material covered so far"
# subtitle: "Stop me if I'm going too fast"
# author:
#   - name: Charles Pletcher
#     affiliations: Tufts University
#     orcid: 0000-0003-2734-5511
#     email: charles.pletcher@tufts.edu
# license:
#   code: MIT
# date: 2025-03-11
# ---
#
# ## TF-IDF - An Introduction
#
# Term Frequency — Inverse Document Frequency, or TF-IDF, is a powerful, if deceptively simple, way of determining keywords in a text. As its name suggests, it is comprised of two parts:
#
# ### Term Frequency (TF)
#
# The number of times that a term — typically, a token or a phrase — appears in a document. We can normalize this using various techniques. Generally speaking, we want to use the _relative_ frequency, or the raw frequency divided by the number of terms in the document.
#
# ### Document Frequency (DF)
#
# The number of documents in which a term appears. Again, there are common normalizations that we will typically perform, such as adding a small ε value to avoid dividing by zero.
#
# _Inverse_ document frequency, or IDF, is just the multiplicative inverse, or reciprocal, of DF.
#
# In practice, however, IDF is usually logarithmically scaled, i.e., $IDF=\log(n/DF)$ where $n$ is the number of documents in the corpus.
#
# ## Prefatory matters
#
# In order to get a sense of a basic implementation of TF-IDF, we first need some text to work with. To get some text, we'll need to review a few things about Python, and we'll need to learn how to use the `lxml` library to get text out of TEI XML files — the kinds of files that store much of the textual data and metadata that we use in digital humanities.
#
# ### Install `lxml`
#
# `%pip` (note the `%`) is a special command built into Jupyter notebooks that lets us use the Python package manager `pip`.
#
# To install a package, we just enter `%pip install` and then the package name in a code cell, like so:

# %%
# %pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-5.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Downloading lxml-5.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 23.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-5.4.0
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import libraries
#
# With `lxml` installed, we now need to import the `etree` library, along with the `Path` constructor from the built-in `pathlib`.

# %%
from lxml import etree
from pathlib import Path

# %% [markdown]
# ### Initialize our path
#
# We'll use the `Path` constructor to grab the XML files that we need to parse:
#
# :::{tip}
# You can read more about **glob patterns** [here](https://code.visualstudio.com/docs/editor/glob-patterns).
# :::

# %%
files = Path("./xml/tlg0012").glob("**/*perseus*.xml")

# %% [markdown]
# ### Set up namespaces for TEI parsing
#
# We also need to define a few namespaces to make it easier to find what we need in the XML files.

# %%
TEI_NS = "http://www.tei-c.org/ns/1.0"
XML_NS = "http://www.w3.org/XML/1998/namespace"

NAMESPACES = {
    "tei": TEI_NS,
    "xml": XML_NS,
}

# %% [markdown]
# ### Process the files
#
# Now we're ready to iterate through the files and extract the text.

# %%
for file in files:
    # print the name of the file as a sanity check
    print(file)
    
    # etree.parse() reads the file and turns the raw XML into an object that we can use in Python
    tree = etree.parse(file)

    # xpath() is a method that applies **xpath expressions** to search through the XML.
    # This xpath expression says, "Find any `tei:div` element with a `subtype` of `'card'`.
    # Under that element, get any text." The second argument, `namespaces=`, tells the
    # method to use the supplied namespaces as shortcuts, so we don't have to type out
    # "http://www.tei-c.org/ns/1.0" every time we want an element in the TEI namespace.

    text = tree.xpath(f"//tei:div[@subtype='card']//text()", namespaces=NAMESPACES)

    # xpath() returns an array of matches, so we initialize an empty array to store the
    # results. We could use a list comprehension, but for now rewriting these
    # lines as a list comprehension is left as an exercise for the reader.
    cleaned_text = []

    # Now we iterate through each string returned by `xpath()`
    for t in text:
        # `strip()` removes leading and trailing whitespace; if all that's left is an empty
        # string, we don't care about it.
        if t.strip != "":
            cleaned_text.append(t.strip())

    # We make sure that we actually *have* text before writing just the text, without
    # TEI elements, to a separate file. No need to write an empty file, right?
    if len(cleaned_text) > 0:
        # A lot is happening here:
        #
        # 1. `str(file)` turns the `Path` object into a `str`
        # 2. `split("/")` splits the resulting string at every "/"
        # 3. `[-1]` takes the last element of the list returned by `split("/")`
        # 4. `replace(".xml", ".txt")` changes the extension of the file
        # 
        # So something like "xml/tlg0012/tlg001/tlg0012.tlg001.perseus-eng3.xml"
        # is transformed into "tlg0012.tlg001.perseus-eng3.txt".
        with open(str(file).split("/")[-1].replace(".xml", ".txt"), "w+") as f:
            # We write the text to the file, `join`-ing each element in
            # `cleaned_text` with a newline ("\n")
            f.write("\n".join(cleaned_text))

# %% [markdown]
# ## TF-IDF in Action
#
# Now that we have our text files, we can start implementing some basic TF-IDF analysis.
#
# First, let's tokenize our text. In the past, we have used `split()` and regular expressions to handle tokenization, but we need to start getting serious about handling punctuation. Let's use the Natural Language Toolkit, or NLTK, instead.
#
# ### Install the NLTK

# %%
# %pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting click (from nltk)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.12/site-packages (from nltk) (1.4.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 37.2 MB/s eta 0:00:00
# Downloading regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (796 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 32.7 MB/s eta 0:00:00
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, click, nltk
#   WARNING: The script tqdm is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed click-8.1.8 nltk-3.9.1 regex-2024.11.6 tqdm-4.67.1
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Download support files
#
# With the NLTK installed, we can now download the support files that it needs for tokenization.

# %%
import nltk

# download the files needed for tokenization
# the punkt tokenizer should be installed already,
# but let's download it just in case
nltk.download("punkt")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to /home/codespace/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# ### Tokenize texts
#
# With the tokenizer downloaded, we can now read in and tokenize each text.

# %%
# Initialize the tokenizer
from nltk.tokenize import word_tokenize

# Initialize an empty dictionary to store the tokenized texts
tokenized_texts = {}

# Get a Path.glob() iterator for the .txt files that you've created in this directory.
# Can you figure out what the new `[1-4]` segment is doing?
text_files = Path(".").glob("tlg0012.tlg00*.perseus-eng[1-4].txt")

# Iterate through the text files, reading and tokenizing them one by one,
# then storing the list of tokens in our `tokenized_texts` dictionary —
# so we'll be getting a dictionary of lists.
for file in text_files:
    name = str(file)

    with open(file) as f:
        # Notice we're lowercasing the text. You don't *have*
        # to do this, but it helps eliminate some noise for
        # our purposes.
        text = f.read().lower()
        tokens = word_tokenize(text)

        # Let's just print the length of the tokens list to make
        # sure we're getting sane results. We'll use string interpolation
        # to identify which text we're working with.
        print(f"There are {len(tokens)} tokens in {name}.")

        # Store each file's `tokens` list in the `tokenized_texts`
        # dictionary, using the filename as the key.
        tokenized_texts[name] = tokens
# Out:
# There are 175611 tokens in tlg0012.tlg001.perseus-eng4.txt.
# There are 200630 tokens in tlg0012.tlg001.perseus-eng3.txt.
# There are 135463 tokens in tlg0012.tlg002.perseus-eng4.txt.
# There are 152631 tokens in tlg0012.tlg002.perseus-eng3.txt.

# %% [markdown]
# ### Count the tokens
#
# Now, we could count these tokens by hand, but why do that when Python gives us the `Counter` object?

# %%
from collections import Counter

# Using our `tokenized_texts` dictionary, we'll iterate
# through each key-value pair — remember, the keys are
# filenames and the values are lists of tokens.
# We'll get a count of the tokens by passing the list to
# `Counter`, then we'll change the value for that key to
# a dictionary with its own keys, `tokens` and `counts`.

for filename, tokens in tokenized_texts.items():
    counts = Counter(tokens)

    tokenized_texts[filename] = {"tokens": tokens, "counts": counts}

# %% [markdown]
# Now we can check to see what our frequencies look like.

# %%
tokenized_texts["tlg0012.tlg001.perseus-eng3.txt"]["counts"]["odysseus"]
# Out:
# 128

# %% [markdown]
# ### Calculate the document frequency for a given term
#
# Let's compare occurrences of the strings `"odysseus"` and `"achilles"` — we probably
# expect the former to "matter" more for the _Odysseus_, and the latter for the _Iliad_. Let's see if that's the case.

# %%
df_achilles = 0
df_odysseus = 0

# Calculate the DF for "odysseus" and "achilles".
# We iterate through the dictionary, and then simply
# count the number of files in which we find each term.
# For these two terms, we should probably expect DFs of 4.
for filename, values in tokenized_texts.items():
    if "odysseus" in values['counts']:
        df_odysseus += 1
    
    if "achilles" in values["counts"]:
        df_achilles += 1

# Now we'll import the log function to calculate the IDF for each term.
from math import log10

n_docs = len(tokenized_texts.keys())

idf_achilles = log10(n_docs / df_achilles)
idf_odysseus = log10(n_docs / df_odysseus)

print(idf_achilles)
# Out:
# 0.0

# %%
# Now let's calculate the TF-IDF "score" for each term in each document.

# Once again, iterate through the dictionary.
for filename, values in tokenized_texts.items():
    # Get the total number of terms in each file — we'll
    # use this to calculate the relative frequency as our
    # TF.
    total_terms = len(values['tokens'])

    # Get the TF for each term in this file.
    tf_achilles = values['counts']['achilles'] / total_terms
    tf_odysseus = values['counts']['odysseus'] / total_terms

    # Remember, the simplest version of TF-IDF is just
    # TF * 1/DF
    tf_idf_achilles = tf_achilles * idf_achilles
    tf_idf_odysseus = tf_odysseus * idf_odysseus

    # Now we can report on the statistics for this file
    print(f"""In {filename}:
TF of achilles: {tf_achilles}
TF of odysseus: {tf_odysseus}
TF-IDF of achilles: {tf_idf_achilles}
TF-IDF of odysseus: {tf_idf_odysseus}
""")
# Out:
# In tlg0012.tlg001.perseus-eng4.txt:
# TF of achilles: 0.002403038534032606
# TF of odysseus: 0.0007061061095261686
# TF-IDF of achilles: 0.0
# TF-IDF of odysseus: 0.0
#
# In tlg0012.tlg001.perseus-eng3.txt:
# TF of achilles: 0.002043562777251657
# TF of odysseus: 0.000637990330459054
# TF-IDF of achilles: 0.0
# TF-IDF of odysseus: 0.0
#
# In tlg0012.tlg002.perseus-eng4.txt:
# TF of achilles: 0.0001254955227626732
# TF of odysseus: 0.0042816119530794386
# TF-IDF of achilles: 0.0
# TF-IDF of odysseus: 0.0
#
# In tlg0012.tlg002.perseus-eng3.txt:
# TF of achilles: 0.0001048279838302835
# TF of odysseus: 0.0041603606082643765
# TF-IDF of achilles: 0.0
# TF-IDF of odysseus: 0.0

# %% [markdown]
# Well, the TF-IDF isn't super interesting, but at least we have the TF to fall back on.
#
# :::{note}
# Can you describe what happened? How might we solve this problem?
# :::

# %% [markdown]
# ### Overcoming frequent words
#
# In such a small corpus, it can be difficult to guess words that don't appear in all documents — certainly names of heroes like Achilles and Odysseus will appear in all of the documents, meaning $\log(n/DF)$ will always be 0.
#
# But we can use the `set()` constructor to find words that do not appear in all of the documents, and calculate TF-IDF on them.
#
# In programming, a **set** is very similar to a list, except it guarantees that it only contains at most 1 of every element.
#
# Let's start small:

# %%
my_list = [1, 1, 2, 3, 3]

set(my_list)
# Out:
# {1, 2, 3}

# %% [markdown]
# Notice how calling `set()` on `my_list` gets rid of the duplicate 1s and 3s. We can do likewise with strings.

# %%
non_universal_terms = {}

for filename, values in tokenized_texts.items():
    my_set = set(values['counts'].keys())

    for other_file, other_values in tokenized_texts.items():
        # make sure we don't compare the file
        # to itself, otherwise the difference
        # will be the empty set
        if other_file != filename:
            my_set -= set(other_values['counts'].keys())
    
    # now push the remaining set of terms to the dictionary
    non_universal_terms[filename] = my_set

# log `non_universal_terms` as a sanity check
non_universal_terms
# Out:
# {'tlg0012.tlg001.perseus-eng4.txt': {'protectress',
#   'enetae',
#   'destitute',
#   'boxwood',
#   'richness',
#   'mule-plowed',
#   'pranks',
#   'hundred-handed',
#   'oppress',
#   'peirar',
#   'sokos',
#   'earth-clash',
#   'foursquare',
#   'damming',
#   'slim-waisted',
#   'ox-hides',
#   'coast-land',
#   'carnage',
#   'coronea',
#   'undaunted',
#   'mid-stream',
#   'flower-bespangled',
#   'havens',
#   'jot',
#   'breastplates',
#   'galley',
#   'kymindis',
#   'renew',
#   'mischief-making',
#   'lights',
#   'decoyed',
#   'skolos',
#   'bellow',
#   'babel',
#   'hindrance',
#   'devote',
#   'by-word',
#   'three-legged',
#   'chances',
#   'lobes',
#   'false-tongued',
#   'lineage.',
#   'adrastos',
#   'spear-stand',
#   'gaping',
#   'unplundered',
#   'spercheios',
#   'handful',
#   'ekhepolos',
#   'storm-cloud',
#   'unbridled',
#   'hide-covered',
#   'pedaios',
#   'askania',
#   'vaunts',
#   'deepened',
#   'humans',
#   'hacked',
#   'wind-beaten',
#   'meliboia',
#   'concert',
#   'testimony',
#   'couples',
#   'sea-nymph',
#   'nay-',
#   'polyneikes',
#   'angle',
#   'simoeis',
#   'excelling',
#   'meteor',
#   'echios',
#   'under-belt',
#   'prothoenor',
#   'makar',
#   'quarrelsome',
#   'notions',
#   'ill-disposed',
#   'liar',
#   'alkimos',
#   'profound',
#   'ratify',
#   'severity',
#   'laogonos',
#   'nesaia',
#   'undismayed',
#   'downwards',
#   'pitting',
#   'charges',
#   'stable-yard',
#   'pain-killing',
#   'disdain',
#   'antaea',
#   'forbearance',
#   'thickens',
#   'unbelted',
#   'reeked',
#   'cajoling',
#   'akamas',
#   'cowed',
#   'runaway',
#   'klonios',
#   'echinean',
#   'scoured',
#   'labored',
#   'hedged',
#   'ebbed',
#   'shirked',
#   'frenzied',
#   'feet-',
#   'hand-',
#   'follow-',
#   'ormenos',
#   'do-',
#   'ken',
#   'transgressed',
#   'lazuli',
#   'dikes',
#   'richly-equipped',
#   'squeaky',
#   'storm-tossed',
#   'deiopites',
#   'hobbled',
#   'surpassing',
#   'relentless',
#   'stalked',
#   'boudeion',
#   'phere',
#   'clattering',
#   'khalkon',
#   'schoinos',
#   'leadership',
#   'lost-',
#   'fervently',
#   'surveyed',
#   'gurgling',
#   'flare',
#   'helos',
#   'aching',
#   'stopping',
#   'expound',
#   'notify',
#   'rattle',
#   'asios',
#   'violate',
#   'foreshadows',
#   'rescued',
#   'fired',
#   'preferring',
#   'majesty',
#   'battle-axe',
#   'schooled',
#   'molos',
#   'damasos',
#   'pylaimenes',
#   'orators',
#   'dissuaded',
#   'preside',
#   'halie',
#   'thigh-bones',
#   'penetrated',
#   'suggestions',
#   'rush-grown',
#   'egged',
#   'hyads',
#   'midea',
#   'towns',
#   'feature',
#   'aithra',
#   'lament-making',
#   'distribute',
#   'phylomedousa',
#   'weddings',
#   'helike',
#   'sulkily',
#   'physicians',
#   'universe',
#   'fork',
#   'oiled',
#   'polyxenos',
#   'winning-post',
#   'timê',
#   'spring-',
#   'chafe',
#   'forgets',
#   'lure',
#   "n't",
#   'courageous',
#   'varne',
#   'hektor.',
#   'saffron-mantled',
#   'ikarian',
#   'never-ending',
#   'warriors-',
#   'master-builder',
#   'disdaining',
#   'weapon',
#   'essaying',
#   'kaineus',
#   'trozen',
#   'sesamus',
#   'awarded',
#   'valleyed',
#   'nestlings',
#   'panope',
#   'defy',
#   'she-mule',
#   'talaos',
#   'stockyard',
#   'pine-trees',
#   'moisten',
#   'flashes',
#   'said-',
#   'ialmenos',
#   'full-speed',
#   'althaia',
#   'seducer',
#   'admetos',
#   'applied',
#   'scatheless',
#   'bowstrings',
#   'arriving',
#   'mold',
#   'near-and-dear',
#   'imprison',
#   'groveling',
#   'hippokoön',
#   'tree-oak',
#   'beings',
#   'aisyetes',
#   'astynoos',
#   'hermos',
#   'lather',
#   'histôr',
#   'ephyroi',
#   'compliment',
#   'exhorting',
#   'daimones',
#   'homesteads',
#   'commit',
#   'lithe',
#   'eyed',
#   'linus-song',
#   'fetching',
#   'fatigued',
#   'leopardess',
#   'astypylos',
#   'opposing',
#   'celery',
#   'alean',
#   'talaimenes',
#   'expects',
#   'boagrios',
#   'grit',
#   'exadios',
#   'calamity',
#   'delicately',
#   'gush',
#   'death-throes',
#   'rabble',
#   'thyrsi',
#   'licyon',
#   'dries',
#   'aithe',
#   'stony',
#   'tips',
#   'lykastos',
#   'outdid',
#   'mother-in-law',
#   'weaken',
#   'local',
#   'implanted',
#   'demands',
#   'fight-',
#   'devours',
#   'sthenelos',
#   'crookedly',
#   'telos',
#   'perea',
#   'mines',
#   'hard-pressed',
#   'fangs',
#   'invitation',
#   'meddle',
#   'accident',
#   'beleaguered',
#   'limped',
#   'extremity',
#   'veering',
#   'pall',
#   'desperate',
#   'well-bolted',
#   'completion',
#   'welkin',
#   'many-delled',
#   'divination',
#   'euenos',
#   'reconciles',
#   'spearsman',
#   'bronze-pointed',
#   'clears',
#   'forfeit',
#   'hand-to-hand',
#   'hyllos',
#   'beaming',
#   'sparrows',
#   'showers',
#   'reaped',
#   'leitos',
#   'bowmen',
#   'persistently',
#   'foundation',
#   'indulge',
#   'swerving',
#   'dagger',
#   'thrash',
#   'plakos',
#   'smarted',
#   'reject',
#   'troizenos',
#   'repel',
#   'thirsting',
#   'quits',
#   'unwashed',
#   'amarynkes',
#   'limpid',
#   'implacable',
#   'boils',
#   'helenos',
#   'halo',
#   'scandea',
#   'rifting',
#   'therefore-and',
#   'additional',
#   'ripening',
#   'drought',
#   'meonians',
#   'foiling',
#   'arkhelokhos',
#   'raided',
#   'plenitude',
#   'knit',
#   'oloosson',
#   'bared',
#   'spear-head',
#   'approval',
#   'brutally',
#   'foot-races',
#   'woodsman',
#   'gatemen',
#   'sulking',
#   'sword-wounds',
#   'pine-tree',
#   'leaped',
#   'askanios',
#   'untied',
#   'eteokles',
#   'maimalos',
#   'far-darter',
#   'life-breath',
#   'strophios',
#   'pattering',
#   'gyrtios',
#   'warden',
#   'bided',
#   'afflicts',
#   'wheel-marks',
#   'fleeter',
#   'remorse',
#   'swarms',
#   'profess',
#   'ledges',
#   'dupe',
#   'arm-rods',
#   'victor',
#   'cross-bar',
#   'settling',
#   'unworthy',
#   'spade',
#   'slightly',
#   'mykalessos',
#   'buds',
#   'stew',
#   'interlaced',
#   'blare',
#   'antimakhos',
#   'aristos',
#   'halizonoi',
#   'avert',
#   'soar',
#   'gloat',
#   'bullock-skins',
#   'waterside',
#   'envoys',
#   'crest-socket',
#   'euphemos',
#   'matrimonial',
#   'brandish',
#   'deep-meadowed',
#   'instruction',
#   'cyprian',
#   'rescue',
#   'middlemost',
#   'thicknesses',
#   'offshoot',
#   'erithinoi',
#   'kteatos',
#   'opheltios',
#   'termagant',
#   'quickest',
#   'erylaos',
#   'risk',
#   'brazen-footed',
#   'yokestraps',
#   'backbone',
#   'impetuously',
#   'you-and',
#   'pronoos',
#   'betides',
#   'bode',
#   'erebos',
#   'metes',
#   'choking',
#   'vindictive',
#   'purposely',
#   'behooves',
#   'crossing',
#   'keladon',
#   'curbed',
#   'gore-bedrabbled',
#   'steeled',
#   'talthybios',
#   'sepulcher',
#   'sheep-yard',
#   'winnowing-shovel',
#   'autophonos',
#   'invade',
#   'woodmen',
#   'ajaxes',
#   'coppice',
#   'indifferent',
#   'buffet',
#   'sallies',
#   'aithikes',
#   'cicadas',
#   'laps',
#   'kicks',
#   'expert',
#   'unite',
#   'titaresios',
#   'infatuated',
#   'tasseled',
#   'courteous',
#   'idaios',
#   'maniac',
#   'resent',
#   'bruise',
#   'asterios',
#   'incited',
#   'claimed',
#   'eteonos',
#   'careless',
#   'sweet-singing',
#   'fledglings',
#   'thwarts',
#   'horse-breeders',
#   'chiron',
#   'fruitling',
#   'bravery',
#   'decrees',
#   'shaped',
#   'heats',
#   'groveled',
#   'blazes',
#   'sincerity',
#   'trumpets',
#   'pheras',
#   'dispensers',
#   'lads',
#   'sharpest',
#   'instructed',
#   'hounded',
#   'calmed',
#   'preference',
#   'skirted',
#   'congratulated',
#   'quoit',
#   'ray',
#   'isos',
#   'exceeded',
#   'pigeon',
#   'thebaios',
#   'ship-building',
#   'old-days',
#   'unfailingly',
#   'pervaded',
#   'wields',
#   'inclines',
#   'overall',
#   'mourns',
#   'blood-',
#   'inflict',
#   'eats',
#   'lyktos',
#   'faded',
#   'intervals',
#   'yoking',
#   'wolf-skin',
#   'roost',
#   'pinnacle',
#   'foolhardiness',
#   'mated',
#   'texture',
#   'butcheries',
#   'karystos',
#   'disposer',
#   'ithaimenes',
#   'sceptered',
#   'bronze-smiths',
#   'exhort',
#   'gallop',
#   'dispatched',
#   'memnêmai',
#   'wedding-feasts',
#   'oath-offerings',
#   'preeminence',
#   'stymphelus',
#   'balearic',
#   'underwood',
#   'self-confident',
#   'continents',
#   'exultant',
#   'stinted',
#   'bathykles',
#   'euippos',
#   'hippolokhos',
#   'demigods',
#   'payment',
#   'amisodoros',
#   'suffused',
#   'many-valleyed',
#   'meekly',
#   'clutches',
#   'frightening',
#   'kallianeira',
#   'flocking',
#   'reconciliation',
#   'phainops',
#   'daitor',
#   'hitherwards',
#   'unheeded',
#   'fainthearted',
#   'decline',
#   'flockmaster',
#   'tow',
#   'dandled',
#   'snows',
#   'philotês',
#   'spear-hounds',
#   'smothered',
#   'wildfire',
#   'hekamede',
#   'cracking',
#   'recovered',
#   'mid-air',
#   'keener',
#   'opposed',
#   'churl',
#   'rinsed',
#   'enjoyment',
#   'fixity',
#   'anxiety',
#   'mown',
#   'transfix',
#   'slinks',
#   'forbidden',
#   'grenicus',
#   'sounder',
#   'overshadow',
#   'clank',
#   'attempted',
#   'shielded',
#   'sticking',
#   'cleverly',
#   'strengthened',
#   'narrowly',
#   'engaging',
#   'bloodstained',
#   'boisterous',
#   'koön',
#   'steeped',
#   'err',
#   'spews',
#   'speo',
#   'hobbling',
#   'ignoble',
#   'showered',
#   'camp-fires',
#   'one-half',
#   'deiochus',
#   'needed',
#   'sthenelaos',
#   'spit-racks',
#   'sangarios',
#   'gargaros',
#   'brimming',
#   'bygones',
#   'inspires',
#   'thrasios',
#   'discomfited',
#   'glories',
#   'mantinea',
#   'double-dyed',
#   'rations',
#   'carelessness',
#   'minyas',
#   'routs',
#   'ankaios',
#   'far-darting',
#   'tmolos',
#   'bryseae',
#   'weak-kneed',
#   'plunder',
#   'saying-',
#   'reflecting',
#   'maker',
#   'dishonored',
#   'swart',
#   'gorgeous',
#   'toppling',
#   'fastness',
#   'encounter-the',
#   'thenceforward',
#   'equipment',
#   'comforting',
#   'boebean',
#   'bystanders',
#   'solymoi',
#   'neighing',
#   'lykophontes',
#   'asteropaios',
#   'cue',
#   'tartaros',
#   'drakios',
#   'clamoring',
#   'induce',
#   'counseling',
#   'apparel',
#   'crocylea',
#   'lapis',
#   'astyochea',
#   'actual',
#   'abians',
#   'disastrous',
#   'pheneus',
#   'recoil',
#   'strayed',
#   'ferret-skin',
#   'dardanos',
#   'satnios',
#   'kissês',
#   'amphigenea',
#   'ungovernable',
#   'hundred-head',
#   'suffice',
#   'javelin-match',
#   'panoply',
#   'lysandros',
#   'presuming',
#   'tries',
#   'scurvy',
#   'phalanxes',
#   'favored',
#   'hooked',
#   'prayer-',
#   'lured',
#   'slobbered',
#   'unpracticed',
#   'sobbed',
#   'exults',
#   'insure',
#   'delicacy',
#   'resumed',
#   'fellow-men',
#   'armlets',
#   'effrontery',
#   'lopped',
#   'four-crested',
#   'ialysos',
#   'klea',
#   'garlands',
#   'head-strong',
#   'oresbios',
#   'workwomen',
#   'allowance',
#   'espying',
#   'pull',
#   'lyrnessos',
#   'sources',
#   'overpower',
#   'podaleirios',
#   'perjure',
#   'chariot-racing',
#   'vault',
#   'aesepos',
#   'unnerved',
#   'swerves',
#   'handsomely',
#   'shrouds',
#   'retreat',
#   'accusing',
#   'blithe',
#   'alektryon',
#   'embank',
#   'zephyros',
#   'gold-bedizened',
#   'chryseis',
#   'meonia',
#   'savior',
#   'hyrtakos',
#   'stable-men',
#   'minister',
#   'counselors',
#   'thymbra',
#   'effaced',
#   'hereby',
#   'finger',
#   'unsoiled',
#   'ceos',
#   'glauke',
#   'slackening',
#   'ousted',
#   'hum',
#   'united',
#   'wine-cup',
#   'asklepios',
#   '-gates',
#   'furnace',
#   'bud',
#   'wounding',
#   'incarnate',
#   'jut',
#   'bench',
#   'phoceans',
#   'smoothing',
#   'accord-',
#   'violation',
#   'clan-gatherings',
#   'kapaneus',
#   'top-rail',
#   'glares',
#   'boros',
#   'sinful',
#   'sea-fight',
#   'confirmation',
#   'untaken',
#   'guilefully',
#   'conversant',
#   'bronze-headed',
#   'daintiest',
#   'kaletor',
#   'divides',
#   'scouring',
#   'welfare',
#   'hillsides',
#   'highways',
#   'thymbraios',
#   'rhodios',
#   'thalysios',
#   'overruling',
#   'uncertain',
#   'irritated',
#   'flours',
#   'mercilessly',
#   'areilykos',
#   'eileithuiai',
#   'deikoön',
#   'grain-growing',
#   'eschew',
#   'kisseus',
#   'commune',
#   'unloosed',
#   'fares',
#   'snags',
#   'herd-heifer',
#   'sleeping-ground',
#   'upraised',
#   'lungs',
#   'uplift',
#   'wended',
#   'akheloos',
#   'almighty',
#   'foster-father',
#   'imbrasos',
#   'pandaros',
#   'opportunity',
#   'heaping',
#   'forage',
#   'graia',
#   'onslaught',
#   'performance',
#   'oreithuia',
#   'kardamyle',
#   'spearsmen',
#   'dion',
#   'right-hand',
#   'outvie',
#   'empire',
#   'unburdened',
#   'metal',
#   'iaira',
#   'train',
#   'soaked',
#   'particular',
#   'parent',
#   'left-hand',
#   'flaring',
#   'fluent',
#   'ame',
#   'all-seeing',
#   'aesopos',
#   'movement',
#   'trifled',
#   'villain',
#   'headstrong',
#   'center',
#   'sea-monsters',
#   'fate-sped',
#   'panthoos',
#   'manfulness',
#   'disobeys',
#   'agastrophos',
#   'ugliest',
#   'trechos',
#   'cousins',
#   'facing-bothways',
#   'sunbeams',
#   'overhead',
#   'steed',
#   'well-nigh',
#   'oinomaos',
#   'subsist',
#   'salvation',
#   'elm-tree',
#   'observance',
#   'relied',
#   'artificers',
#   'interrupt',
#   'languish',
#   'alight',
#   'leaps',
#   'task-master',
#   'serviceable',
#   'pursuers',
#   'archilokhos',
#   'pluck',
#   'clots',
#   'trickster',
#   'hard-hearted',
#   'alkandros',
#   'intentions',
#   'thump',
#   'triple-barbed',
#   'kallikolone',
#   'sole',
#   'medesikaste',
#   'spear-wound',
#   'cleaver',
#   'sea-monster',
#   'shivered',
#   'praktios',
#   'self-reliance',
#   'unperceived',
#   'steward',
#   'nerve',
#   'resolute',
#   'comforter',
#   'polydoros',
#   'dismounted',
#   'bouprasion',
#   'arbitrator',
#   'struggles',
#   'mete',
#   'philoi',
#   'thoe',
#   'silver-eddying',
#   'crystal',
#   'evildoer',
#   'compassionately',
#   'bribed',
#   'gamboling',
#   'amaze',
#   'goodwill',
#   'kebriones',
#   'outposts',
#   'antrum',
#   'scabbarded',
#   'gale-',
#   'excepting',
#   'behead',
#   'steams',
#   'marshaling',
#   'likymnios',
#   'fore-arm',
#   'acquit',
#   'resplendent',
#   'phradmon',
#   'tychios',
#   'beleaguering',
#   'flute',
#   'sedition',
#   'councilor',
#   'aphthitos',
#   'cloud-compelling',
#   'detailed',
#   'surgeon',
#   'self-confidence.',
#   'lykomedes',
#   'minyeios',
#   'melanthos',
#   'off-spring',
#   'bunches',
#   'pylaios',
#   'sea-wrack',
#   'branded',
#   'whizzing',
#   'wreaked',
#   'suing',
#   'breastworks',
#   'aisyme',
#   'severs',
#   'disquieted',
#   'whisks',
#   'imploringly',
#   'grateful',
#   'monger',
#   'worshipped',
#   'rock-perched',
#   'meonian',
#   'gallops',
#   'straining',
#   'cheek-pierced',
#   'overjoyed',
#   'peneus',
#   'buckles',
#   'sheepyards',
#   'hangs',
#   'parleying',
#   'lowermost',
#   'bedchambers',
#   'justly',
#   'kharites',
#   'myrrhine',
#   'sword-blow',
#   'disaffection',
#   'autonoos',
#   'spares',
#   'eye-brows',
#   'heptaporos',
#   'eussoros',
#   'nestled',
#   'uprooting',
#   'starting-post',
#   'bronzed',
#   'wriggling',
#   'elated',
#   'whistle',
#   'harmlessly',
#   'six-year',
#   'wielding',
#   'civil',
#   'themistes',
#   'plays',
#   'persisted',
#   'money',
#   'collar-bones',
#   'assarakos',
#   'echeklos',
#   'polymelos',
#   'a-weeping',
#   'menaced',
#   'inexorable',
#   'echekles',
#   'dignity',
#   'sternness',
#   'resembled',
#   'dizzy',
#   'spiteful',
#   'chaff-',
#   'highlands',
#   'broach',
#   'hiding-place',
#   'pant',
#   'blindly',
#   'preceding',
#   'wide-spreading',
#   'awards',
#   'continuous',
#   'ever-beating',
#   'all-counseling',
#   'peaceably',
#   ...},
#  'tlg0012.tlg001.perseus-eng3.txt': {'dius',
#   'fearlessly',
#   'wasteth',
#   'such-like',
#   'larisa',
#   '309.1',
#   'wrought—nay',
#   'augur—these',
#   'watch-fires',
#   'well-fitted',
#   'mingleth',
#   'rain-drops',
#   'not—verily',
#   'trusteth',
#   'knelt',
#   'wands',
#   'atone',
#   'firm-fixed',
#   'men—a',
#   'felling',
#   'undone—to',
#   'skilless',
#   'feastings',
#   'entreatment',
#   'compacts',
#   'sthenelus',
#   'passeth',
#   'face—i',
#   'boast—on',
#   'getteth',
#   'blacker',
#   'affright',
#   'autonous',
#   'cephisus',
#   '515.1',
#   'outran',
#   '209.1',
#   'diveth',
#   'phrygian',
#   'athene',
#   'marshallers',
#   'atymnius',
#   'rendered',
#   'dammed',
#   'vehement',
#   'callicolone',
#   'winnower',
#   'turning-points',
#   'yoketh',
#   'madest',
#   'cutteth',
#   'apportioned',
#   'cypris',
#   'lance',
#   'exultest',
#   'sparks',
#   'keenliest',
#   'simoïs',
#   'causeth',
#   'apportion',
#   'thatch',
#   'glens',
#   'swing',
#   'salt-sea',
#   'lunged',
#   'promptings',
#   'thrasius',
#   'well-woven',
#   'vauntingly',
#   'close-fenced',
#   'quenching',
#   'gazeth',
#   'heedeth',
#   'river—and',
#   'plaintively',
#   'beateth',
#   'through—',
#   'abreast',
#   'orchards',
#   'waggons',
#   'enfolding',
#   'speedy',
#   'dulled',
#   '13.1',
#   'better—',
#   'profiteth',
#   'towered',
#   'come—sore',
#   'eneti',
#   'bronze—and',
#   'hyrtius',
#   'laërtes',
#   'holdeth',
#   'th',
#   'ariseth',
#   'many-ridged',
#   'down—lest',
#   'outstripped',
#   'axylus',
#   'chideth',
#   'scandeia',
#   'presseth',
#   'slaving',
#   'handmaiden',
#   'sounded',
#   'demesne-land',
#   'plough—then',
#   'apportionment',
#   'falcons—',
#   'feareth',
#   'fie',
#   'oozeth',
#   'rods',
#   'oversea',
#   'loveth',
#   'echo',
#   'achdeans',
#   'autophonus',
#   'eared',
#   'surpasseth',
#   'heraldship',
#   'haughtinesses',
#   'amidst',
#   'seizeth',
#   "'twere",
#   'pheme',
#   'vexeth',
#   'ohd',
#   'achaeans—',
#   'one—seeing',
#   'man-child',
#   'plummet',
#   'cornfield',
#   'cherishes',
#   'deïcoön',
#   'bane—to',
#   'sore-pressed',
#   'scantier',
#   'exist',
#   'sovreignty',
#   'enjoined',
#   'heaped-up',
#   'grapple',
#   'be-neath',
#   'blackened',
#   'wavered',
#   'euneos',
#   'stared',
#   'orphan',
#   'teat—',
#   'poureth',
#   'corpse—the',
#   'amphinone',
#   'cymodoce',
#   'battle—unwitting',
#   'many—my',
#   'softer',
#   'cringed',
#   'summoning',
#   'crutch',
#   'enquirest',
#   'digged',
#   'pards',
#   'deviseth',
#   'robbeth',
#   'atreus—for',
#   "'twixt",
#   'scantiest',
#   'betake',
#   'ship—and',
#   'overmaster',
#   'glorified',
#   'castianeira',
#   'blunt',
#   'glareth',
#   'shaketh',
#   'all-nurturing',
#   'eïoneus',
#   'unlooked-for',
#   'appeasement',
#   'spercheüs',
#   'prayed—to',
#   'pried',
#   'standest',
#   'polypoetes',
#   'consenteth',
#   'faltered',
#   'joyeth',
#   'thick-hidden',
#   'exulteth',
#   'assuaged',
#   'eilithyiae',
#   'aud',
#   'imbrius',
#   'dishonoured',
#   'oïleus',
#   'stripling',
#   'mattock',
#   'livedst',
#   'sitteth',
#   'upbringing',
#   'eleans',
#   'cteatus',
#   'bird-diviners',
#   'aegaeon',
#   'overweeningly',
#   'echepolus',
#   'upbraids',
#   'cunningly-wrought',
#   'left—',
#   'heaveth',
#   'bearers',
#   'war-loving',
#   'launching-ways',
#   'lyco',
#   'immortals—how',
#   'drinking-bouts',
#   'stabbed',
#   'renegade',
#   'adrastus',
#   'urgest',
#   'wist',
#   'changeth',
#   'shay',
#   'ten-fold',
#   'venturous',
#   'palate',
#   'boebeïs',
#   'rolleth',
#   'glistering',
#   'hippemolgi',
#   'high-hearted',
#   'labouring',
#   'chargeth',
#   'bowmanship',
#   'offereth',
#   'wordrous',
#   'hades—even',
#   'sheddeth',
#   'breast—nay',
#   'ploughmen',
#   'all-unscathed',
#   'out-runneth',
#   'it—yet',
#   'demuchus',
#   'aiantes',
#   'uprisen',
#   'boastings',
#   'amarynceus',
#   'guarding',
#   'loerians',
#   'gat',
#   'slayeth',
#   'petted',
#   'rageth',
#   'balius',
#   'antiphonus',
#   'croucheth',
#   'sakes',
#   'kingship',
#   'tychius',
#   'cleobulus',
#   'break-down',
#   'side-traces',
#   'archelochus',
#   'life—even',
#   'declaring',
#   'aflame',
#   'giveth',
#   'wide-flowing',
#   'thrice-prayed-for',
#   'send—even',
#   'paeëon',
#   'prayeth',
#   'herds-men',
#   'showest',
#   'unspeakable—wolves',
#   'belloweth',
#   'better—to',
#   '331.1',
#   'rosettes',
#   'warped',
#   'be.and',
#   'stymphalus',
#   'dare—and',
#   'antimachus',
#   'halizones',
#   'antilochos',
#   'swift-streaming',
#   'foot-men',
#   'gargarus',
#   'floweth',
#   'daze',
#   'tartarus',
#   'pleadings',
#   'offerest',
#   'open-mouthed',
#   '69.1',
#   '395.1',
#   'bank—a',
#   'allurements',
#   'god—upon',
#   'destroyeth',
#   'burners',
#   'stretcheth',
#   'hither-ward',
#   'ower',
#   'reprisal',
#   'resoundeth',
#   'eëtion',
#   'harbours',
#   '161.2',
#   'bringeth',
#   'twittered',
#   'intervene',
#   'whomso',
#   'halcyon-bird',
#   'unblest',
#   "whoe'er",
#   'high-gated',
#   'aegialus',
#   'others—pitiless',
#   '519.1',
#   'aepytus',
#   'pandarus',
#   'feebly',
#   'soundeth',
#   'more.',
#   'aforetimethou',
#   'nastes—nastes',
#   '229.1',
#   'sepulchre',
#   'irketh',
#   'enters',
#   'phausius',
#   'far—let',
#   'sea-beasts',
#   'smooth-barked',
#   'immortals-',
#   'sweepeth',
#   'eumelas',
#   "whatsoe'er",
#   'inviolable',
#   'fear—for',
#   'gable-rafters',
#   'soul—nay',
#   'gave—even',
#   'box-wood',
#   'spear-thrusts',
#   'bethougnt',
#   'lung',
#   'frantic',
#   'prefer',
#   '565.2',
#   'sideward',
#   '43.1',
#   'devoureth',
#   'piaited',
#   'fightest',
#   'entering-in',
#   'counteth',
#   'consorteth',
#   'billowy',
#   'highway',
#   'cythem',
#   'afloat',
#   'gaped',
#   'axius',
#   'no—for',
#   'names—of',
#   'loosenlng',
#   'measurehess',
#   'astyalus',
#   'fleeth',
#   'men—asius',
#   'regardeth',
#   'abii',
#   'abydus',
#   'departeth',
#   'glauce',
#   'despiteful',
#   '—no',
#   '29.1',
#   'plain—being',
#   'fleest',
#   'hed',
#   '153.1',
#   'fulfilleth',
#   'car—the',
#   'lamentings',
#   'themselves—even',
#   'wainwright',
#   'comers',
#   'all-gleaming',
#   'midmost',
#   'celadon',
#   '53.2',
#   'telamon—fools',
#   "'why",
#   'slumbering',
#   'breast-straps',
#   '557.1',
#   'recking',
#   'planteth',
#   'orithyia',
#   'streaming',
#   'cruelty',
#   'titaressus',
#   'linos-song',
#   'younglings',
#   'applauding',
#   'zeus-nurtured',
#   'sea-waves',
#   'rouseth',
#   'shield-men',
#   'racked',
#   'percote',
#   'menestheus—and',
#   'coileth',
#   'washen',
#   '199.1',
#   'chalcon',
#   'prone',
#   'bronze-harnessed',
#   'joineth',
#   'battle-din',
#   'sayeth',
#   'teil',
#   'lysander',
#   'euphorbus',
#   'forgat',
#   'loiter',
#   'outstay',
#   'troezenus',
#   'wide-scattered',
#   'senseless',
#   'pliant',
#   '159.1',
#   'caucones',
#   'forging',
#   'destined',
#   'decayeth',
#   'colour',
#   'obdurate',
#   'mountainside',
#   'hopeth',
#   'yore',
#   'sintian',
#   'putteth',
#   'excessive',
#   'forebodeth',
#   'home-return',
#   'insults',
#   'poising',
#   'riseth',
#   'love—as',
#   'infallible',
#   'baleful',
#   'broiderings',
#   'deïochus',
#   'crusheth',
#   'ensnareth',
#   'him—for',
#   'channel—',
#   'dip',
#   'dressing',
#   'hinu',
#   'telamonian',
#   'haze',
#   'admetus',
#   'tear-fraught',
#   'helpeth',
#   'helmet-ridges',
#   'rangeth',
#   'frieads',
#   'home-going',
#   'asteropaeus',
#   'chieftans',
#   'leagued',
#   '379.1',
#   'taut',
#   'vanquisheth',
#   'tasselled',
#   'ninth—so',
#   'ceaseth',
#   'outthrew',
#   'dight',
#   'sware',
#   'beseemeth',
#   'bespake',
#   'asaeus',
#   'stealing',
#   'meed',
#   'thelr',
#   'withdrawing',
#   'boileth',
#   'afresh',
#   'melting-vats',
#   'new-wrought',
#   'speweth',
#   'hippomachus',
#   'fillies',
#   'license',
#   'fareth',
#   'deïphobus',
#   'amain',
#   'thitherward',
#   '0',
#   'sorrowed',
#   'alpheius',
#   'baldrics—',
#   'ogler',
#   'dodonaean',
#   'over-haughty',
#   'company.',
#   'cowered',
#   'well-twisted',
#   'bodeth',
#   '—that',
#   'nesaea',
#   'whomever',
#   'contriver',
#   'hippolochus',
#   'slew.',
#   'mill-stone',
#   'arraying',
#   'liveth',
#   'shuddereth',
#   'mount—yet',
#   'feathered',
#   'eëriboea',
#   'thoön',
#   'anemoreia',
#   'go—it',
#   'wetteth',
#   'kerchief',
#   'pedasus',
#   'leaguer',
#   'dallied',
#   'danaë',
#   'trustv',
#   'hands—',
#   'hah',
#   'xanthus',
#   'remembering',
#   'agrius',
#   'threateneth',
#   'reviler',
#   'dishonour',
#   'caystrius',
#   'aiders',
#   'tempest-blast',
#   'arm-bands',
#   'beholdest',
#   'bronze-smith',
#   'shrill-sounding',
#   'zeus—even',
#   'rake',
#   'ochesius',
#   'bendeth',
#   'mellay',
#   'maemalus',
#   'disorderly',
#   'four-horned',
#   'jewels',
#   'shifteth',
#   'gasped',
#   '551.1',
#   'stud',
#   'aethices',
#   'dooms',
#   'nooks',
#   'clonius',
#   'stooping',
#   'her—fair',
#   'shapeth',
#   'watcheth',
#   'buildeth',
#   'she-mules',
#   'practius',
#   '329.1',
#   'dancing-floor',
#   'zeus—born',
#   'lesser',
#   'caenus',
#   '565.1',
#   'aleian',
#   '319.2',
#   'euphemus',
#   'corpse—for',
#   'entereth',
#   'sorrowless',
#   'trace-horse',
#   'ber',
#   'succour',
#   'mastereth',
#   'meted',
#   'knight',
#   'unprofitable',
#   'declareth',
#   'son—he',
#   '33.1',
#   'awaken',
#   'althaea',
#   'mayhap',
#   'neareat',
#   'chaplets',
#   'defilement',
#   'parthenius',
#   'scattereth',
#   'are—yet',
#   'trickling',
#   'younger-born',
#   'niight',
#   'anvil-block',
#   'anything—who',
#   'unheedful',
#   'finst',
#   'wandereth',
#   'rum',
#   'bespeak',
#   'phlegyes',
#   'weaving-rod',
#   'rift',
#   'strife—will',
#   'suborned',
#   'butt',
#   'hasted',
#   '311.1',
#   'wardeth',
#   'strivings',
#   'swiftfooted',
#   'bronze-greaved',
#   'alalcomenean',
#   'protesilaus',
#   'raging—thitherward',
#   'chiefly',
#   'rivalry',
#   'aepeia',
#   'meagre',
#   'battling',
#   'vouch-safe',
#   'stone—a',
#   'asian',
#   'contrariwise',
#   'gentle-mindedness',
#   'way-farer',
#   'fire-dogs',
#   'heart—it',
#   'forgettest',
#   'overtopped',
#   'polydorus',
#   'sputtering',
#   'setteth',
#   '59.1',
#   'vehemence',
#   'astynous',
#   'swine-herd',
#   'fair-growing',
#   'pynope',
#   'fatal',
#   'begat—',
#   'harnesses',
#   'roareth',
#   'stinging',
#   'hypeiron',
#   'doest',
#   'quaff',
#   'medesicaste',
#   'dog-fly',
#   'ennomus',
#   'coucheth',
#   'bristleth',
#   'honoureth',
#   'schedius',
#   'ephyri',
#   'war-toil',
#   'ot',
#   'uncounted',
#   'elm',
#   'biding',
#   '—would',
#   'augeias',
#   'agave',
#   'haemon',
#   'lulleth',
#   'dwelleth',
#   'valour',
#   'ox-goad',
#   'long-tarrying',
#   'courseth',
#   'worketh',
#   'more—and',
#   'wise-hearted',
#   'actaeä',
#   'succoureth',
#   'augeiae',
#   'pteleos',
#   'over-much',
#   'host.',
#   'weigheth',
#   'deemeth',
#   'honoured',
#   'consolation',
#   'cheiron',
#   'exacting',
#   'gambolled',
#   'simois',
#   'newly-twisted',
#   'underbrush',
#   'boastest',
#   'bivouac',
#   'raiseth',
#   '291.1',
#   'quick-glancing',
#   'vineland',
#   'harnesseth',
#   'smitest',
#   'surest',
#   'helicaon',
#   'amphigeneia',
#   'unsacked',
#   'molus',
#   'idaeus',
#   'vuhtures',
#   'endued',
#   'discerned—there',
#   'deed—one',
#   'pergamus',
#   'fleshing-block',
#   'divisions—in',
#   'thole',
#   'gnaw',
#   'creaked',
#   'thing—to',
#   'honour',
#   'vexing',
#   'breaketh',
#   'knotted',
#   'overmastered',
#   'trechus',
#   'rampart',
#   'iphinous',
#   'tilleth',
#   'toiling',
#   'payest',
#   'idleness',
#   'magnify',
#   'aesyetes',
#   'thereover',
#   'afright',
#   'heareth',
#   'biddeth',
#   'hyrtacus',
#   'lodged',
#   'spurted',
#   'elders—to',
#   'hurtling',
#   'thrusteth',
#   'spaclous',
#   'ganymedes',
#   'floateth',
#   'loth',
#   'spearthrust',
#   'bestirring',
#   'unrelentingly',
#   'spool',
#   'half-talent',
#   'many-benched',
#   'neighed',
#   'ilean',
#   'wayfaring',
#   'doer',
#   'pursueth',
#   'numbed',
#   'this—a',
#   'scamander',
#   'urgeth',
#   'foolhardy',
#   'neglectful',
#   'zone',
#   'eudorus',
#   '—not',
#   'satnius',
#   'mailed',
#   'flutter',
#   'wreaths',
#   'fluently',
#   '—the',
#   'son—his',
#   'elder-born',
#   'axius—axius',
#   '419.2',
#   'wind-footed',
#   'ear-rings',
#   'suiting',
#   'fodder',
#   'penning',
#   'embassage',
#   'calesius',
#   'journeying',
#   'peered',
#   '325.1',
#   'simples',
#   'adornment',
#   'turning-point',
#   'workest',
#   'ox-eyed',
#   'swift-glancing',
#   'ialmenus',
#   'athrob',
#   'incomplete',
#   'tree-trunks',
#   'mountain-dwelling',
#   'rejoiceth',
#   'draweth',
#   'hooved',
#   'crocyleia',
#   'chid',
#   '—if',
#   'over-hanging',
#   'marshalled',
#   'well-inhabited',
#   '407.1',
#   'horse-man',
#   'stead-fast',
#   '563.1',
#   'dismiss',
#   'diligent',
#   'neeks',
#   'sufficeth',
#   'peleus—in',
#   'vaunteth',
#   'fleddest',
#   'confounded',
#   'swift-falling',
#   'reproachfully',
#   'apollos',
#   'pursue—even',
#   'loathsome',
#   'mycalessus',
#   'lyctus—for',
#   'them—the',
#   'slumberest',
#   '—zeus',
#   'pleasure—the',
#   'availeth',
#   'idaean',
#   'clamour',
#   'hippodamus',
#   '423.2',
#   'clytomedes',
#   'burneth',
#   'wight',
#   'durst',
#   'echinae',
#   'deadliest',
#   'waging',
#   'forearm',
#   '—hold',
#   'undermost',
#   '—asius',
#   'fair-fashioned',
#   'knoweth',
#   'farm-stead',
#   'on-coming',
#   'lengthy',
#   'well-plaited',
#   'saffron-robed',
#   'arcesilaus',
#   'weepest',
#   'amny',
#   'gorged',
#   'caeneus',
#   'melanippus',
#   'babbler',
#   'dracius',
#   'serves',
#   'rotteth',
#   'birth-place',
#   'soul-devouring',
#   'them—even',
#   'scorned',
#   'swifted-footed',
#   'boasteth',
#   'thiem',
#   'palaces',
#   'men-at-arms',
#   'rage—',
#   'curiously-wrought',
#   'leech',
#   'guest-friends',
#   'feil',
#   "o'erleap",
#   'iron—ten',
#   'discern',
#   'delighting',
#   'achaia',
#   'hollowed',
#   'halting',
#   'bodv',
#   'moat',
#   'separated',
#   'dalliance—beguilement',
#   'coronus',
#   'gyrtius',
#   'coon',
#   'pandocus',
#   'helpmeet',
#   'deemest',
#   'smitings',
#   'unheard',
#   'caletor',
#   'spear-cast',
#   'summoneth',
#   'garden-lots',
#   'pleiades',
#   'pylaemenes',
#   'givest',
#   'ones—even',
#   'fallow-land',
#   'fondled',
#   'combatants',
#   'lionhearted',
#   'soft-hearted',
#   'dulichiuni',
#   'tangle',
#   'water-snake',
#   'hunger-pangs',
#   'annointed',
#   'pitifully',
#   'iphiclus',
#   'uttermost',
#   'looketh',
#   'prized',
#   'crashed',
#   'ptolemaeus',
#   'isus',
#   'lop',
#   'sword—for',
#   'slinketh',
#   'astyocheia',
#   'daysman',
#   '289.1',
#   'sangarius',
#   'welded',
#   'sceptre-holding',
#   'erylaus',
#   'broidering',
#   'now—for',
#   'trustest',
#   'soothed',
#   'speakers',
#   'clave',
#   'mischief—one',
#   'everywhither',
#   'thanksgivings',
#   'cymindis',
#   'straineth',
#   '13.2',
#   'whichsoever',
#   'onsets',
#   'groweth',
#   'cleareth',
#   'agape',
#   'hipponous',
#   '419.1',
#   'there-through',
#   'fierce—',
#   'troians',
#   'nurtureth',
#   'whelm',
#   'unfed',
#   'sword—were',
#   'well-builded',
#   'marsh',
#   'unwon',
#   'aide',
#   'i—i',
#   'overturn',
#   'casteth',
#   'deft',
#   'gape',
#   'man-hood',
#   'schoenus',
#   'grimmest',
#   'monnment',
#   'raveth',
#   'overpowering',
#   '527.1',
#   'peiros',
#   'tugs',
#   'thwarted',
#   'spewing',
#   'shriek',
#   'howl',
#   'wrathful',
#   'breathing-space',
#   'revereth',
#   'anigh',
#   ...},
#  'tlg0012.tlg002.perseus-eng4.txt': {'living.',
#   'chimneys',
#   'gourmet',
#   'gold-enthroned',
#   'colors',
#   'antlered',
#   'wretchedly',
#   'matrimony',
#   'dances',
#   'mooring',
#   'dikaios',
#   'breadbaskets',
#   'enlisting',
#   'frightful',
#   'pious',
#   'honors',
#   'cheaper',
#   'nightfall',
#   'steadying',
#   'squally',
#   'wiliness',
#   'bedroom',
#   'fisherman',
#   'series',
#   'instinct',
#   'casks',
#   'hemming',
#   'peisistratos',
#   'cooking',
#   'age-mate',
#   'rude',
#   'issued',
#   'consulted',
#   'geraistos',
#   'wrecks',
#   'overrun',
#   'pinch',
#   'pretext',
#   'commission',
#   'importunity',
#   'foreboded',
#   'incorrigible',
#   'lookers',
#   'dirty',
#   'wrinkles',
#   'fraud',
#   'magnificently',
#   'voyage.',
#   'saluted',
#   'impossible',
#   'hoeing',
#   'mentioned',
#   'trap',
#   'lowering',
#   'squalid',
#   'ripens',
#   'pyriphlegethon',
#   'stoutest',
#   'avenging',
#   'claws',
#   'scarred',
#   'boyhood',
#   'damp',
#   'reasonably',
#   'filed',
#   'liquor',
#   'coasts',
#   'upholds',
#   'glide',
#   'riverhood',
#   'shocked',
#   'colonized',
#   'unsettling',
#   'chickens',
#   'rapids',
#   'people-',
#   'kreon',
#   'krînô',
#   'dreamed',
#   'house-keeper',
#   'staircase',
#   'sicel',
#   'recalling',
#   'heaven-sent',
#   'bow-fancier',
#   'somebody',
#   'redound',
#   'enchant',
#   'minyan',
#   'dogfish',
#   'strong-box',
#   'notices',
#   'fishy',
#   'thoughtfulness',
#   'parties',
#   'tapestries',
#   'figures',
#   'shambles',
#   'ravaged',
#   'peaceful',
#   'feckless',
#   'perilous',
#   'history',
#   'interpretation',
#   'transgress',
#   'arnaios',
#   'house-top',
#   'kerdea',
#   'overhear',
#   'torch-light',
#   'krounoi',
#   'inhabitants',
#   'subtlety',
#   'foul-mouthed',
#   'abounds',
#   'gatekeeper',
#   'drowned',
#   'ill-conditioned',
#   'position',
#   'cleaned',
#   'eternity',
#   'packing',
#   'deafening',
#   'intercourse',
#   'liberal',
#   'enamel',
#   'jumpers',
#   'alighting',
#   'immoderately',
#   'lively',
#   'conclude',
#   'crew.',
#   'revelers',
#   'oldest',
#   'jumping',
#   'warning',
#   'connected',
#   'to.',
#   'outlines',
#   'raisins',
#   'adored',
#   'apeira',
#   'melanthios',
#   'eurylokhos',
#   'squeal',
#   'shoo',
#   'akastos',
#   'honestly',
#   'phronios',
#   'widely',
#   'swinging',
#   'ill-natured',
#   'kissing',
#   'result',
#   'amply',
#   'shift',
#   'questioning',
#   'steersmen',
#   'fuller-handed',
#   'prowls',
#   'relate',
#   'squat',
#   'risked',
#   'aigyptos',
#   'deities',
#   'ridiculous',
#   'nervous',
#   'strictly',
#   'disguising',
#   'wonderfully',
#   'sucking',
#   'misgave',
#   'grill',
#   'rigorously',
#   'bolder',
#   'tidy',
#   'promontory',
#   'anchor',
#   'purse',
#   'depends',
#   'tallied',
#   'impress',
#   'eurymakhos',
#   'astounded',
#   'growls',
#   'infancy',
#   'amphialos',
#   'lavishly',
#   'drunkenness',
#   'overran',
#   'un-cared',
#   'resuming',
#   'ungrafted',
#   'bedside',
#   'it-',
#   'discreditable',
#   'neighboring',
#   'carding',
#   'citizens',
#   'exactly',
#   'clapping',
#   'attempt',
#   'comings',
#   'trooping',
#   'forceful',
#   'freemen',
#   'suck',
#   'encircle',
#   'superhuman',
#   'capturing',
#   'entranced',
#   'bleeds',
#   'leukas',
#   'pounded',
#   'sights',
#   'fish-like',
#   'hatchet',
#   'instinctive',
#   'accordingly',
#   'close-in',
#   'shipwreck',
#   'advantageous',
#   'diplomacy',
#   'cleaning',
#   'becalmed',
#   'work-box',
#   'volunteers',
#   'dinner-party',
#   'victuals',
#   '=',
#   'movingly',
#   'selected',
#   'accounting',
#   'atmosphere',
#   'descendants',
#   'shoveled',
#   'expectations',
#   'fuddle',
#   'unblended',
#   'agonies',
#   'enormous',
#   'sluts',
#   'dare-devil',
#   'handle-holes',
#   'anybody',
#   'unwasted',
#   'nêpenthes',
#   'aft',
#   'fort',
#   'neat',
#   'amnisos',
#   'convinced',
#   'eurykleia',
#   'style',
#   'aver',
#   'swindler',
#   'principles',
#   'thrives',
#   'behavior',
#   'scolded',
#   'screams',
#   'unharnessed',
#   'well-to-do',
#   'shiver',
#   'sheep-stealing',
#   'serious',
#   'rankle',
#   'bliss',
#   'tubs',
#   'reclined',
#   'fish-fag',
#   'juts',
#   'free-booters',
#   'detain',
#   'repair',
#   'munch',
#   'backstay',
#   'shamefaced',
#   'mixing-jugs',
#   'nation',
#   'astonish',
#   'punished',
#   'resume',
#   'unpick',
#   'obliged',
#   'hurdles',
#   'wanderers',
#   'bait',
#   'motioned',
#   'neaira',
#   'ikarios',
#   'evenings',
#   'kindnesses',
#   'beauties',
#   'detaining',
#   'good-bye',
#   'telemos',
#   'noses',
#   'proceeded',
#   'horizon',
#   'absence.',
#   'bondsman',
#   'conversations',
#   'obstacles',
#   'lend',
#   'colored',
#   'introduce',
#   'disrespectful',
#   'woe-begone',
#   'peering',
#   'removing',
#   'detested',
#   'adding',
#   'athletes',
#   'shoals',
#   'crop',
#   'celebrated',
#   'broken-hearted',
#   'bounty',
#   'loveliness',
#   'ktesippos',
#   'exploits',
#   'landing',
#   'drip',
#   'hereabouts',
#   'flavor',
#   'sacrificial',
#   'damask',
#   'abusing',
#   'tambour',
#   'tapestry',
#   'illustrious',
#   'solace',
#   'crimson',
#   'well-mated',
#   'blue',
#   'swaggering',
#   'intrigue',
#   'furnished',
#   'ceiling',
#   'guilds',
#   'netted',
#   'day-break',
#   'funeral.',
#   'sex',
#   'poorer',
#   'severe',
#   'unaccountable',
#   'diverted',
#   'creditable',
#   'unrecorded',
#   'good-naturedly',
#   'formerly',
#   'tour',
#   'spending',
#   'festivities',
#   'innocent',
#   'leda',
#   'genuine',
#   'wonders',
#   'displayed',
#   'cruse',
#   'gossiping',
#   'relief',
#   'admirable',
#   'lessons',
#   'pomp',
#   'pins',
#   'shabby',
#   'prodigies',
#   'persistent',
#   'daughters-in-law',
#   'reflected',
#   'enmity',
#   'mutual',
#   'cross-piece',
#   'summertime',
#   'offices',
#   'tidily',
#   'ortilokhos',
#   'telepylos',
#   'demodokos',
#   'gunwale',
#   'sea-king',
#   'bustled',
#   'ornaments',
#   'consciences',
#   'pestering',
#   'alkinoos',
#   'many-sided',
#   'high-handedly',
#   'wooden',
#   'square',
#   'still.',
#   'charming',
#   'sheathe',
#   'prospered',
#   'terror-struck',
#   'hive',
#   'aurora',
#   'rotting',
#   'disparaging',
#   'athlêtês',
#   'insubstantial',
#   'interceded',
#   'tracks',
#   'miller-women',
#   'knock',
#   'excuse',
#   'thunder-bolts',
#   'munching',
#   'exit',
#   'heaven-taught',
#   'pig',
#   'traveled',
#   'sea-horses',
#   'leukothea',
#   'dragon',
#   'behave',
#   'ensconced',
#   'okyalos',
#   'baring',
#   'conscience-stricken',
#   'presume',
#   'persist',
#   'seal',
#   'good-for-nothing',
#   'sympathy',
#   'expression',
#   'forge',
#   'gadding',
#   'center-piece',
#   'epikaste',
#   'damaged',
#   'hundreds',
#   'flatter',
#   'absurd',
#   'kindly-natured',
#   'accompanied',
#   'thistledown',
#   'magician',
#   'spirited',
#   'murdering',
#   'personal',
#   'resins',
#   'levy',
#   'painlessly',
#   'immeasurably',
#   'apiece',
#   'amphinomos',
#   'ache',
#   'fits',
#   'amassed',
#   'unrighteously',
#   'travels',
#   'persuasive',
#   'witchcraft',
#   'abundance.',
#   'overflow',
#   'inheritance',
#   'pigsty',
#   'govern',
#   'decently',
#   'extraordinarily',
#   'continual',
#   'anabesineos',
#   'true-begotten',
#   'ripping',
#   'amphiaraos',
#   'biâ',
#   'plainness',
#   'ethiopia',
#   'naughtiness',
#   'lances',
#   'acre',
#   'spends',
#   'accurately',
#   'subscriptions',
#   'weakened',
#   'second-rate',
#   'fire-seed',
#   'periklymenos',
#   'musically',
#   'stagger',
#   'site',
#   'uneaten',
#   'well-tilled',
#   'inquiring',
#   'positive',
#   'belief',
#   'brush-wood',
#   'bleached',
#   'proofs',
#   'bribes',
#   'floats',
#   'fret',
#   'detest',
#   'hurts',
#   'messenians',
#   'singular',
#   'travel',
#   'capable',
#   'once.',
#   'contended',
#   'doubled',
#   'clapped',
#   'lengthways',
#   'envelop',
#   'twenty-four',
#   'disrespect',
#   'thesprotian',
#   'grafted',
#   'hint',
#   'yells',
#   'wakefully',
#   'frame',
#   'tricks',
#   'exhausted',
#   'side-wind',
#   'reduced',
#   'pretense',
#   'cheese-racks',
#   'patron',
#   'safest',
#   'discomfits',
#   'compose',
#   'vestibule',
#   'threes',
#   'increasing',
#   'grandmother',
#   'modest',
#   'butchered',
#   'menial',
#   'lean-to',
#   'nausithoos',
#   'resemble',
#   'crunch',
#   'usual',
#   'professed',
#   'boring',
#   'fortune-telling',
#   'shifted',
#   'clamorous',
#   'apt',
#   'crime',
#   'shoes',
#   'bed-prop',
#   'deserve',
#   'daytime',
#   'clubbed',
#   'exception',
#   'lodging',
#   'ox-thong',
#   'credit',
#   'inches.',
#   'wrecking',
#   'originally',
#   'accompaniment',
#   'hospitably',
#   'scrolls',
#   'ivy-wood',
#   'belonged',
#   'everyone',
#   'surf-beaten',
#   'moody',
#   'heinous',
#   'outcry',
#   'curly',
#   'heaving',
#   'horseback',
#   'miraculous',
#   'swamp',
#   'goddess.',
#   'interest',
#   'offended',
#   'aigyptios',
#   'reprimand',
#   'beckoned',
#   'inhuman',
#   'grossly',
#   'sailor',
#   'crows',
#   'pretty',
#   'transport',
#   'water-sprinkling',
#   'gilding',
#   'limp',
#   'scarf',
#   'scoundrel',
#   'perfidy',
#   'glowing',
#   'admittance',
#   'likes',
#   'rangers',
#   'deign',
#   'syra',
#   'fifty-two',
#   'ointments',
#   'likelihood',
#   'apatê',
#   'actually',
#   'drunkard',
#   'enthroned',
#   'peopled',
#   'alkandra',
#   'grandfather',
#   'reality',
#   'savory',
#   'valuables',
#   'complain',
#   'warmly',
#   'enriches',
#   'salute',
#   'cretan',
#   'prison',
#   'supposing',
#   'crowning',
#   'splendors',
#   'domed',
#   'nods',
#   'papyrus',
#   'regained',
#   'plaguing',
#   'dresses',
#   'hulking',
#   'suggested',
#   'aimlessly.',
#   'insist',
#   'ill-behaved',
#   'continues',
#   'parts.',
#   'crossbeams',
#   'dozen',
#   'tramps',
#   'pigsties',
#   'foresworn',
#   'indoors',
#   'better-looking',
#   'aspen',
#   'carvers',
#   'schemer',
#   'smelling',
#   'privateering',
#   'overhung',
#   'forebodings',
#   'well-looking',
#   'coppers',
#   'beautified',
#   'banqueting-room',
#   'excellency',
#   'solitary',
#   'forenoon',
#   'shabby-looking',
#   'washing-cisterns',
#   'depreciate',
#   'piloted',
#   'muzzled',
#   'youngster',
#   'worrying',
#   'watered',
#   'amuse',
#   'appearance',
#   'forcefully',
#   'squaring',
#   'gloomy',
#   'intention',
#   'anticipates',
#   'blacksmith',
#   'oikleus',
#   'easy-going',
#   'drubbing',
#   'practice',
#   'importunate',
#   'tiptoe',
#   'chivalry',
#   'misled',
#   'twenty-oared',
#   'banqueting',
#   'townspeople',
#   'jelly',
#   'dowry',
#   'ripped',
#   'precincts',
#   'seriously',
#   'juryman',
#   'ill-treat',
#   'topes',
#   'festooned',
#   'waking',
#   'phemios',
#   'tortures',
#   'sighing',
#   'sundry',
#   'stronghold',
#   'interrupted',
#   'cell',
#   'bubbled',
#   'mistrust',
#   'wayfarers',
#   'ekhthroi',
#   'firelight',
#   'emptied',
#   'bearing-posts',
#   'sufficient',
#   'foggy',
#   'bargaining',
#   'center-post',
#   'earshot',
#   'coverings',
#   'bards',
#   'hooting',
#   'soared',
#   'treatment',
#   'ogygian.',
#   'elysium',
#   'permanently',
#   'passages',
#   'solitude',
#   'ultimately',
#   'reach.',
#   'misfortunes',
#   'flagging',
#   'trees.',
#   'walking',
#   'bearing-post',
#   'sundown',
#   'pat',
#   'cajoled',
#   'peloponnese',
#   'starve',
#   'eumaios',
#   'strainers',
#   'straightening',
#   'handsome',
#   'shuttles',
#   'truly.',
#   'thawed',
#   'islet',
#   'torture',
#   'slut',
#   'bags',
#   'pits',
#   'deathlike',
#   'plaintive',
#   'sided',
#   'reports',
#   'comfortingly',
#   'obtaining',
#   'cloisters',
#   'refitting',
#   'bread-baskets',
#   'require',
#   'purchased',
#   'explained',
#   'remark',
#   'outlive',
#   'merge',
#   'adventures',
#   'powerfully',
#   'expedition',
#   'ones.',
#   'eclipse',
#   'fleas',
#   'sidonia',
#   'fattening',
#   'cairn',
#   'scowling',
#   'interesting',
#   'horrified',
#   'inches',
#   'completely',
#   'lives.',
#   'stubbornness',
#   'grunted',
#   'awed',
#   'conceivable',
#   'salutations',
#   'constancy',
#   'ikmalios',
#   'boil',
#   'breezy',
#   'firstly',
#   'sunrise',
#   'propitiation',
#   'siding',
#   'group',
#   'patiently',
#   'inextinguishable',
#   'insisted',
#   'gobbets',
#   'krataiis',
#   'coxswain',
#   'demoptolemos',
#   'world.',
#   'sea-gulls',
#   'meadowsweet',
#   'asopos',
#   'purely',
#   'leans',
#   'long-suffering',
#   'nericum',
#   'foothold',
#   'goatskins',
#   'honesty',
#   'thong-hole',
#   'cleanses',
#   'sicels',
#   'alkmaion',
#   'moderation',
#   'affect',
#   'ebb',
#   'admiration',
#   'defying',
#   'patience',
#   'visibly',
#   'partner',
#   'acquaintance',
#   'swaying',
#   'strategy',
#   'clever',
#   'privately',
#   'poets',
#   'conjecture',
#   'naturally',
#   'forewarn',
#   'sheepskin',
#   'drugged',
#   'disorder',
#   'scrubbed',
#   'bloodlessly',
#   'scampered',
#   'misadventure',
#   'raiding',
#   'workmanlike',
#   'lump',
#   'propitious',
#   'dresser',
#   'attacks',
#   'spit',
#   'pounced',
#   'behaving',
#   'damage',
#   'injury',
#   'sweethearts',
#   'cooked',
#   'feather',
#   'rode',
#   'freights',
#   'quaking',
#   'soot',
#   'allows',
#   'aglow',
#   'dispute',
#   'ktesios',
#   'steaming',
#   'chance.',
#   'feelings',
#   'anyhow',
#   'dispensation',
#   'acquainted',
#   'allow',
#   'competing',
#   'distressing',
#   'manure',
#   'rejoined',
#   'hussies',
#   'snap',
#   'foresaw',
#   'mash',
#   'dispatch',
#   'ancestors',
#   'apartments',
#   'preach',
#   'mysterious',
#   'bleared',
#   'propriety',
#   'tooth',
#   'pleasuring',
#   'independent',
#   'fire-eater',
#   'fruitlessly',
#   'bruises',
#   'monarch',
#   'feat',
#   'honeyed',
#   'ducts',
#   'foretold',
#   'nimblest',
#   'toys',
#   'contemptuously',
#   'difference',
#   'competitions',
#   'elect',
#   'superintend',
#   'water-loving',
#   'soften',
#   'admiring',
#   'polite',
#   'expounded',
#   'reeking',
#   'striven',
#   'pottering',
#   'brambles',
#   'equals',
#   'onto',
#   'unfortunate',
#   'loading',
#   'pontonoos',
#   'lamos',
#   'dikai',
#   'beggarly',
#   'antikleia',
#   'chop',
#   'louts',
#   'egging',
#   'reclining',
#   'eurynomos',
#   'intolerably',
#   'impulse',
#   'magistrate',
#   'hearers',
#   'scandalous',
#   'pavement',
#   'saluting',
#   'drown',
#   'apprehend',
#   'virgin',
#   'rejects',
#   'expected',
#   'rapt',
#   'perfection',
#   'astonishment',
#   'itylos',
#   'despairingly',
#   'vainest',
#   'leveled',
#   'klymenos',
#   'salutes',
#   'massacre',
#   'peacefulness',
#   'briefly',
#   'overflowing',
#   'growl',
#   'rills',
#   'timely',
#   'humming',
#   'snaring',
#   'fact',
#   'gardener',
#   'affectionate',
#   'unfriendly',
#   'kisses',
#   'customary',
#   'country-farm',
#   'persons',
#   'habit',
#   'iros',
#   'disturbance',
#   'tyndarus',
#   'clamored',
#   'difficulties',
#   'providence',
#   'imposing',
#   'usher',
#   'valuable',
#   'studied',
#   'irrepressible',
#   'tournament',
#   'irrigate',
#   'picture',
#   'shuddering',
#   'withholds',
#   'powder',
#   'venerable',
#   'chamois',
#   'athlete',
#   'schemes',
#   '-but',
#   'jumped',
#   'believes',
#   'voyages',
#   '-lay',
#   'land-locked',
#   'nothing.',
#   'injure',
#   'boötes',
#   'blandishment',
#   'dipping',
#   'poorest',
#   'frowned',
#   'afternoon',
#   'travelers',
#   'giantess',
#   'verbal',
#   'ghost',
#   'magnificent',
#   'bevy',
#   'fine-looking',
#   'stories',
#   'loitering',
#   ...},
#  'tlg0012.tlg002.perseus-eng3.txt': {'things—who',
#   'phronius',
#   'consort',
#   'complete',
#   'hummed',
#   'monsters',
#   'rub',
#   'nectar.',
#   'mending',
#   'outlying',
#   'house—proud',
#   'somewhat.',
#   'feebleness',
#   'two-fold',
#   'oarsmen—that',
#   'lackest',
#   'requital.',
#   'webs',
#   'slave-women',
#   'syria',
#   'mantius',
#   'cavern—all',
#   'last.',
#   'feed.',
#   'hauled',
#   'confirmed',
#   'casts',
#   'abound.',
#   'curled',
#   'variance',
#   'stoutly-bound',
#   'mind—tell',
#   'bronze—not',
#   'lower—they',
#   'gainful',
#   'avoids',
#   'porticoes',
#   'elsewhere.',
#   'mastered',
#   'parents—would',
#   'one—for',
#   'chins',
#   'woman—amazement',
#   'peltings',
#   'fellow—a',
#   'unseemly—but',
#   'grief.',
#   'ready.',
#   'unmanned.',
#   'clings',
#   'pelasgians',
#   'scooped',
#   'designed',
#   'many-voiced',
#   'feud',
#   'aegyptus',
#   'me—my',
#   'these.',
#   'planks',
#   'outworn.',
#   'guiltless.',
#   'wieldest',
#   'corax',
#   'aeetes',
#   'crosses',
#   'thyself.',
#   'icarius',
#   'dismantled',
#   'both.',
#   'drained',
#   'forgetting',
#   'others.',
#   'close-barred',
#   'oarblades',
#   'eurymachus',
#   'spiders',
#   'unripe',
#   'scurf',
#   'unhonored',
#   'curve',
#   'eye.',
#   'fawningly',
#   'wrongs.',
#   'islands—dulichium',
#   'close-fitting',
#   'heaven.',
#   'ctesius',
#   'possessions.',
#   'bewitch',
#   'home-coming',
#   'pitied.',
#   'sorts—whensoever',
#   'polyneus',
#   'passers-by',
#   'cheerless',
#   'consorted',
#   'road-steads',
#   'thee—hail',
#   'afterward',
#   'thralls',
#   'today',
#   'near.',
#   'accompaniments',
#   'overlays',
#   'sowing',
#   'phaethusa',
#   'assume',
#   'overseen',
#   'persephone—',
#   'sing.',
#   'telemus',
#   'decisive',
#   'assembly—for',
#   '4',
#   'mockery',
#   'die.',
#   'fast.',
#   'piloting',
#   'ivy',
#   'bones.',
#   'ox-chine',
#   'peisistratus',
#   'maimer',
#   'bridles',
#   'envelops',
#   'devise.',
#   'clear-seen',
#   'alms',
#   'tarriest',
#   'far-off',
#   'downcast',
#   'fairer',
#   'skulks',
#   'wooers—fools',
#   'powerless',
#   'southwest',
#   'befits',
#   'scour',
#   'gloves',
#   'unfailing',
#   'things—',
#   'above.',
#   'well-washed',
#   'buying',
#   'basest',
#   'boethous',
#   'falcons',
#   'well-fatted',
#   'thee—hounds',
#   'erectheus',
#   'bedabbled',
#   'dimmed',
#   'traveller',
#   'business.',
#   'stone.',
#   'overseer',
#   'carpentry',
#   'good-for-naught',
#   'eye—',
#   'reared.',
#   'begirt',
#   'gladsome',
#   'richer',
#   'marriage.',
#   'owest',
#   'mates',
#   'unclear',
#   'antinous',
#   'chasm',
#   'sawest',
#   'god.',
#   'unwinged',
#   'zethus',
#   'psyria',
#   'alector',
#   'athena.',
#   'reply',
#   'bed-fellow',
#   'drill',
#   'sand-spits',
#   'spoil.',
#   'consortest',
#   'warrant',
#   'bed—bedstead',
#   'threateningly',
#   'ortilochus',
#   'purpose.',
#   '—thy',
#   'tender-heartedness',
#   'cureless',
#   'odysseus.',
#   'reproach.',
#   'offerings—there',
#   'far.',
#   'unravelling',
#   'sun—and',
#   'turning-places',
#   'eyelids—but',
#   'thrive',
#   'dolius',
#   'grief—unless',
#   'roves',
#   'freight-ship',
#   'forth.',
#   'trustiest',
#   'potent',
#   'eurycleia',
#   'last—even',
#   'iphicles',
#   'blessed.',
#   'supreme.',
#   'epeus',
#   'laertes.',
#   'smear',
#   'lawlessness—ctesippus',
#   'halls—two',
#   'irus',
#   'sun—a',
#   'earth—two',
#   'hireling',
#   'appoint',
#   'amphiaraus',
#   'head-gear',
#   'for.',
#   'weeps.',
#   'sleep.',
#   'afar.',
#   'drive—the',
#   'seethe',
#   'welcome.',
#   'statelier',
#   'shadow',
#   'tityos',
#   'stab',
#   'foot.',
#   'banqueters',
#   'question.',
#   'revolved',
#   'kitchen-wife',
#   'core',
#   'wife.',
#   'bed-post',
#   'evade',
#   'perishes',
#   'hairy',
#   'passes',
#   'hall.',
#   'rest.',
#   'barter',
#   'oneself',
#   'well-watered',
#   'pegs',
#   'cloak.',
#   'guardest',
#   'notes',
#   'exact',
#   'bow-tip',
#   'crouni',
#   'unmilked',
#   'enquiry',
#   'flask',
#   'playthings',
#   'god—who',
#   'minstrels.',
#   'dishes',
#   'arise.',
#   'sore-tired',
#   'owes',
#   'wrenched',
#   'spirals',
#   'trotted',
#   'rivals',
#   'trial—for',
#   'greenwood',
#   'oared',
#   'insolence.',
#   'boon—honor',
#   'anticlus',
#   'lapithae',
#   'hirelings',
#   'neatherd',
#   'achilles.',
#   'them—he',
#   'ruin.',
#   'poseidon—a',
#   'bonds.',
#   'oar-blades',
#   'much.',
#   'helius',
#   'distressed.',
#   'doors—straightway',
#   'unmoored',
#   'destruction.',
#   'graciously',
#   'females',
#   'assails',
#   'toil-worn',
#   'endure.',
#   'thought—i',
#   'achaea.',
#   'dainties',
#   'scyros',
#   'osiers',
#   'tempestuously',
#   'contest.',
#   'bow.',
#   'swiftly-falling',
#   'belched',
#   'forbear.',
#   'men—meanwhile',
#   'convoy',
#   'carving',
#   'across—and',
#   'goats—he',
#   'stature.',
#   'baits',
#   'tone',
#   'deep.',
#   'tracking',
#   'close-fitted',
#   'risings',
#   '—where',
#   'us—who',
#   'weighted',
#   'time.',
#   'strength.',
#   'vigorous',
#   'sure.',
#   'arm.',
#   'quicken',
#   'nameless',
#   'bores',
#   'waned',
#   'arnaeus',
#   'limb.',
#   'prayer.',
#   'sicilians',
#   'dust—all',
#   'binds',
#   'float',
#   'compulsion',
#   'look.',
#   'this—or',
#   '”',
#   'frisk',
#   'pranced',
#   'wrest',
#   'obtain',
#   'earned',
#   'costliest',
#   'purge',
#   'weaves',
#   'ebbing',
#   'unmannerly',
#   'lends',
#   'propping',
#   'god—',
#   'invoice',
#   'forwardness',
#   'scatters',
#   'finely-wrought',
#   'pelted',
#   'seagirt',
#   'expectantly',
#   'icmalius',
#   'boom',
#   'escape.',
#   'perished.',
#   'man-destroying',
#   'marvellously',
#   'day.',
#   'kindness.',
#   'many—aye',
#   'child—unless',
#   'bleated',
#   'paeeon',
#   'treacherous',
#   'them—verily',
#   'fortune.',
#   'spellbound',
#   'sins',
#   'oversees',
#   'gaea',
#   'worth.',
#   'rich.',
#   'two-eared',
#   '—grievous',
#   'regret',
#   'weaving—',
#   'torment.',
#   'belly.',
#   'feast.',
#   'will—no',
#   'notest',
#   'scorns',
#   'males—the',
#   'beneath—a',
#   'achaeans—the',
#   'begrudge',
#   'abstain',
#   'days.',
#   'things.',
#   'soothingly',
#   'forever',
#   'profitable',
#   'hand-washing',
#   'carven',
#   'moving',
#   'unmanned',
#   'reputed',
#   'treacherous.',
#   'heart—a',
#   'mills',
#   'shoved',
#   'melantheus',
#   'rejoicing.',
#   'life.',
#   'reeling',
#   'crack-brained',
#   'warm.',
#   'craftsmen',
#   'fringed',
#   'bloodshed.',
#   'words.',
#   'blossomed',
#   'palisades',
#   'broad-eared',
#   'yelping',
#   'hiding-places',
#   'athlete.',
#   'portionless',
#   'resting-place',
#   'meadow-land',
#   'deep-moaning',
#   'uprightly.',
#   'remembers',
#   'stalls',
#   'line—',
#   'clymenus',
#   'harrows',
#   'indeed.',
#   'upholding',
#   'dome',
#   'valor.',
#   'winnowing-fan',
#   'reefs—for',
#   'easiest',
#   'tilted',
#   'response',
#   'marriage—',
#   'wide-spread',
#   'ethiopians—the',
#   'round-shouldered',
#   'roaming',
#   'substance.',
#   'eurymedusa',
#   'entertains',
#   'philoetius',
#   'crusted',
#   'evenor',
#   'wavers',
#   'strew',
#   'himself.',
#   'hoes',
#   'fiery-pointed',
#   'thrice-ploughed',
#   'spurned',
#   'compels',
#   'nericus',
#   'no-wise',
#   'jewel',
#   'jet',
#   'fuller',
#   'aegisthus',
#   'hoof',
#   'frets',
#   'quaffs',
#   'scares',
#   'lede',
#   '—nor',
#   'trusts',
#   'windward',
#   'achaens',
#   'townsmen',
#   'rite',
#   'colts',
#   'true-born',
#   'handicraft',
#   'melanthius.',
#   'was—to',
#   'best.',
#   'paced',
#   'of.',
#   'joy.',
#   'yard-arm',
#   'loosened—then',
#   'land.',
#   'cross-beams',
#   'pasturing',
#   'abase',
#   'sight.',
#   'door-stone',
#   'circe.',
#   'evening.',
#   'wheedling',
#   'hunger.',
#   'ctesippus',
#   'fair-stablished',
#   'finely-spun',
#   'theoclymenus',
#   'awaking',
#   'named.',
#   'thine.',
#   'wailings',
#   'crackled',
#   'worse.',
#   'thee—gathering',
#   'oftenest',
#   'withal—that',
#   'unchanged',
#   'murders',
#   'afar—for',
#   'unawakening',
#   'polycaste',
#   'bilge',
#   'us—',
#   'thaws',
#   'knavish',
#   'soul-consuming',
#   'times—and',
#   'anticleia',
#   'hollows',
#   'full.',
#   'postern',
#   'unheeding',
#   'noble.',
#   'unversed',
#   'eurynomus',
#   'purging',
#   'price.',
#   'soiled—there',
#   'door-post',
#   'grey-headed',
#   'stout-clawed',
#   'reef',
#   'force.',
#   'acastus',
#   'amphialus',
#   'in.',
#   'achieves',
#   'vaulted-over',
#   'doorposts',
#   'endue',
#   'hand.',
#   'reefs',
#   'this—what',
#   'greets',
#   'halls.',
#   'met.',
#   'un-irused',
#   'fore-stays',
#   'aught.',
#   'strength—and',
#   'dangers',
#   'weaned',
#   'befalls',
#   'stronger.',
#   'water—this',
#   'wretchedness',
#   'groanings—gifts',
#   '—fool',
#   'slight',
#   'undertook',
#   'laughable',
#   'knaves',
#   'water.',
#   'grazing—all',
#   'gad-fly',
#   'graceless',
#   'out-stripped',
#   'strokes',
#   'visitest',
#   'guiding',
#   'troubled.',
#   'doorpost',
#   'rehearsed',
#   'belches',
#   'scratches',
#   'desirest.',
#   'all—one',
#   'high-horned',
#   'prelude',
#   'trimming',
#   'melampus',
#   'phaedimus',
#   'comelier',
#   'bethinks',
#   'shunned',
#   'cities.',
#   'piling',
#   'flock.',
#   'ashamed.',
#   'multitudinous',
#   'shadows.',
#   'pays',
#   'comprehend',
#   'pines',
#   'hand—a',
#   'home—even',
#   'mirth',
#   'twirl',
#   'whit—',
#   'slunk',
#   'friends.',
#   'passion.',
#   'garden-plot',
#   'bedims',
#   'intertwining',
#   'night.',
#   'deep-lowing',
#   'threatens',
#   'suffering.',
#   'landwards',
#   'thrice-blessed',
#   'silenced',
#   'sunium',
#   'bustle',
#   'frown',
#   'long-oared',
#   'down.',
#   'cliffs—then',
#   'was—even',
#   'thereafter.',
#   'stuffs',
#   'anoints',
#   'myriad',
#   'constant',
#   'aphrodite.',
#   'show.',
#   'scraped',
#   'bountifully',
#   'dealings',
#   'bade—though',
#   'calledst',
#   'kings.',
#   'pictures',
#   'on.',
#   'fellow.',
#   'cross-planks',
#   'plentiful',
#   'enquired',
#   'gifted',
#   'wizard',
#   'giants.',
#   'faired-haired',
#   'sword-hilt',
#   'heart—high',
#   'trade',
#   'babes',
#   'long-winged',
#   'aghast',
#   'nurture',
#   'any.',
#   'bubble',
#   'sea-eagles',
#   'wanders',
#   'sore-tried',
#   'unrighteousness',
#   'upon.',
#   'invoke',
#   'ladder',
#   'bellies—then',
#   'wane',
#   'keeper',
#   'anchored',
#   'alcandre',
#   'helper.',
#   'broods',
#   'beguiles',
#   'suppliant.',
#   'acroneus',
#   'cravens',
#   'recounting',
#   'vales',
#   'maro',
#   'look—as',
#   'sweet-smelling',
#   'fair-wrought',
#   'quailest',
#   'ilius',
#   'truth.',
#   'teaching',
#   'impious',
#   'thou.',
#   'new-sawn',
#   'willow',
#   'say.',
#   'overcast',
#   'launching',
#   'stewardess',
#   'desiring',
#   'marrowy',
#   'naught—so',
#   'husband.',
#   'plunging',
#   'ferrymen',
#   'gulp',
#   'brine-bred',
#   'unravel',
#   'beaches',
#   'choose.',
#   'heritage',
#   'strong.',
#   'was—',
#   'oar-loving',
#   'rainy',
#   'adulterer.',
#   'chafing',
#   'someday',
#   'stout-hoofed',
#   'stranger—i',
#   'spins',
#   'judged',
#   'gold.',
#   'it—for',
#   'alone.',
#   'wouldest.',
#   'boastful',
#   'pinning',
#   'submittest',
#   'onward—soon',
#   'brace',
#   'maidens.',
#   'made.',
#   'plenteous',
#   'rags.',
#   'racking',
#   'contrivings',
#   'ocyalus',
#   'season.',
#   'mate',
#   'raiment.',
#   'dancing-floors',
#   'earth.',
#   'strengthening',
#   'ripen',
#   'fugitive',
#   'achaeans.',
#   'man-eater',
#   'abound',
#   'farest',
#   'woos',
#   'fair—so',
#   'perils.',
#   'armour.',
#   'spinners',
#   'oh',
#   'autolycus.',
#   'splitting',
#   'prayed-for',
#   'robe—i',
#   'sea—and',
#   'will—for',
#   'throw.',
#   'maidservants',
#   'another—',
#   'descry',
#   'decent',
#   'demodocus',
#   'shews',
#   'alcmaeon',
#   'recess',
#   'spell-bound',
#   'mid-sea',
#   'water-grass',
#   'deck-beams',
#   'acts',
#   'harmest',
#   'telemachus.',
#   'stairway',
#   'neriton',
#   'men—as',
#   'closely-woven',
#   'self-taught',
#   'eumaeus',
#   'hearkenened',
#   'me—for',
#   'booming',
#   'people.',
#   'guidance',
#   'home—that',
#   'gulfs',
#   'phemius',
#   'doorway.',
#   'fruit—there',
#   'weds',
#   'see.',
#   'ismarus',
#   'widespread',
#   'side—even',
#   'seemly.',
#   'nuisances',
#   'watched.',
#   'depend.',
#   'misty',
#   'scrip',
#   'meeting-places',
#   'hazarding',
#   'eilithyia',
#   'gazes',
#   'nausithous',
#   'vagabonds',
#   'yearns',
#   'that.',
#   'trunk',
#   'skilful',
#   'alcippe',
#   'coverlets—that',
#   'drinking-bout',
#   'lessened',
#   'it—a',
#   'sorrow—',
#   'gulps',
#   'speech.',
#   'have.',
#   'thrinacia',
#   'stratius',
#   'immortals.',
#   'steered',
#   'aegis.',
#   'aid.',
#   'cleanest',
#   'fitteth',
#   'wares',
#   'continuously',
#   'ship-wrights',
#   'merchantmen',
#   'mind.',
#   'behove',
#   'lodge',
#   'blows.',
#   'besets',
#   'enquiring',
#   'ogygia',
#   'oicles',
#   'vermin',
#   'perforce.',
#   'bright-throned',
#   'pleasure—',
#   'distributed',
#   'thinkest',
#   'masters—',
#   'criest',
#   'well.',
#   'mounts',
#   'roundabout',
#   'here.',
#   'they—men',
#   'roof.',
#   'separately.',
#   'gone.',
#   'city.',
#   'goodly.',
#   '—in',
#   'ctimene',
#   'am.',
#   'desist.',
#   'rend.',
#   'outdo',
#   'boors',
#   'footsteps.',
#   'deeds.',
#   'piraeus',
#   'wood.',
#   'meal.',
#   'death-struggle',
#   'lading-plank',
#   'quarrels',
#   'unfalteringly',
#   'demoptolemus',
#   'kindred',
#   'describest',
#   '3',
#   'deigned',
#   'evil.',
#   'wind.',
#   'ignorance',
#   'folly.',
#   'passer-by',
#   'talkest',
#   'tiding',
#   'plain-told',
#   'settlement',
#   'ephialtes—men',
#   'morticings',
#   'barely',
#   'comest',
#   'well-wooded',
#   'atonement.',
#   'dissent',
#   'costly',
#   "would'st",
#   'wine-bowl',
#   'land—his',
#   'shewn',
#   'obey.',
#   'ailed',
#   'baffling',
#   'aeaea',
#   'gleams',
#   'answer—verily',
#   'another.',
#   'newest',
#   'acheans',
#   'tearless',
#   'eurylochus',
#   'zeus.',
#   'pleasure.',
#   'was.',
#   'unprovoked',
#   'child.',
#   'thought.',
#   'suppliants.',
#   'foe.',
#   'trenches',
#   'streamlet',
#   'too—farewell',
#   'naught—ate',
#   'eurymus',
#   'boars.',
#   'echetus',
#   'wallet.',
#   'electrum',
#   'endured.',
#   'porous',
#   'supplies',
#   'robe—',
#   'leucas',
#   'finely',
#   'forests.',
#   'wrought—many',
#   'sways',
#   'strangers—zeus',
#   'contriving',
#   'myself.',
#   'simple-minded',
#   'juniper',
#   'phaeacians.',
#   'provoked',
#   'deed.',
#   'store-rooms',
#   'bootes',
#   'long-shanked',
#   'aegyptius',
#   'leiocritus',
#   'sicilian',
#   'travailing',
#   'man—why',
#   'sea-mew',
#   'curly-haired',
#   'assurance',
#   'befooling',
#   'wakens',
#   'decree',
#   'hades.',
#   'ambling',
#   'jeered',
#   'dastardly',
#   'resolve',
#   'fiery-hoofed',
#   'dwelling—who',
#   'telemachus—for',
#   'two-and-twenty',
#   'wooest',
#   'woody',
#   'valiance',
#   'debating',
#   'cuttlefish',
#   'blooming',
#   'fives',
#   'apollo—for',
#   'roof-beam',
#   'fulfil',
#   'growling',
#   'isle.',
#   'home-borne',
#   'trim',
#   'crataiis',
#   'pear-trees',
#   'bossy',
#   'desires.',
#   'faultless',
#   'reviling.',
#   'shame.',
#   'sunder',
#   'establish',
#   'feastest',
#   'lacks',
#   'rust—',
#   'rolls',
#   ...}}

# %% [markdown]
# ## Your turn
#
# Now that you've seen the basics of TF-IDF, use the `set`s that we've built to explore the values for several terms in this corpus.
#
# As you explore, make note of any findings that seem odd — are they errors in how we have run the analysis, or is the text just weird?
#
# Consider, too, how you might improve the analysis in the future.
#
# Then in your own words, describe _what_ TF-IDF is really telling us about a given term in each text and within the corpus as a whole.
#
# Finally, think about other objects of study for which TF-IDF might be useful.

# %%
df_polyxenos = 0
df_balearic = 0
df_phalanxes = 0
df_sheepyards = 0

# Calculate the DF for "odysseus" and "achilles".
# We iterate through the dictionary, and then simply
# count the number of files in which we find each term.
# For these two terms, we should probably expect DFs of 4.
for filename, values in tokenized_texts.items():
    if "polyxenos" in values['counts']:
        df_polyxenos += 1
    
    if "balearic" in values["counts"]:
        df_balearic += 1

    if "phalanxes" in values["counts"]:
        df_phalanxes += 1
    
    if "sheepyards" in values["counts"]:
        df_sheepyards += 1

# Now we'll import the log function to calculate the IDF for each term.
from math import log10

n_docs = len(tokenized_texts.keys())

idf_polyxenos = log10(n_docs / df_polyxenos)
idf_balearic = log10(n_docs / df_balearic)
idf_phalanxes = log10(n_docs / df_phalanxes)
idf_sheepyards = log10(n_docs / df_sheepyards)

print(idf_polyxenos)
print(idf_balearic)
print(idf_phalanxes)
print(idf_sheepyards)
# Out:
# 0.6020599913279624
# 0.6020599913279624
# 0.6020599913279624
# 0.6020599913279624

# %%
# Now let's calculate the TF-IDF "score" for each term in each document.

# Once again, iterate through the dictionary.
for filename, values in tokenized_texts.items():
    # Get the total number of terms in each file — we'll
    # use this to calculate the relative frequency as our
    # TF.
    total_terms = len(values['tokens'])

    # Get the TF for each term in this file.
    tf_polyxenos = values['counts']['polyxenos'] / total_terms
    tf_balearic = values['counts']['balearic'] / total_terms
    tf_phalanxes = values['counts']['phalanxes'] / total_terms
    tf_sheepyards = values['counts']['sheepyards'] / total_terms

    # Remember, the simplest version of TF-IDF is just
    # TF * 1/DF
    tf_idf_polyxenos = tf_polyxenos * idf_polyxenos
    tf_idf_balearic = tf_balearic * idf_balearic
    tf_idf_phalanxes = tf_phalanxes * idf_phalanxes
    tf_idf_sheepyards = tf_sheepyards * idf_sheepyards

    # Now we can report on the statistics for this file
    print(f"""In {filename}:
            TF of polyxenos: {tf_polyxenos}
            TF of balearic: {tf_balearic}
            TF of phalanxes: {tf_phalanxes}
            TF of sheepyards: {tf_sheepyards}
            TF-IDF of polyxenos: {tf_idf_polyxenos}
            TF-IDF of balearic: {tf_idf_balearic}
            TF-IDF of phalanxes: {tf_idf_phalanxes}
            TF-IDF of sheepyards: {tf_idf_sheepyards}"""
            )
# Out:
# In tlg0012.tlg001.perseus-eng4.txt:
#             TF of polyxenos: 5.694404109082005e-06
#             TF of balearic: 5.694404109082005e-06
#             TF of phalanxes: 1.7083212327246014e-05
#             TF of sheepyards: 5.694404109082005e-06
#             TF-IDF of polyxenos: 3.4283728885318253e-06
#             TF-IDF of balearic: 3.4283728885318253e-06
#             TF-IDF of phalanxes: 1.0285118665595476e-05
#             TF-IDF of sheepyards: 3.4283728885318253e-06
# In tlg0012.tlg001.perseus-eng3.txt:
#             TF of polyxenos: 0.0
#             TF of balearic: 0.0
#             TF of phalanxes: 0.0
#             TF of sheepyards: 0.0
#             TF-IDF of polyxenos: 0.0
#             TF-IDF of balearic: 0.0
#             TF-IDF of phalanxes: 0.0
#             TF-IDF of sheepyards: 0.0
# In tlg0012.tlg002.perseus-eng4.txt:
#             TF of polyxenos: 0.0
#             TF of balearic: 0.0
#             TF of phalanxes: 0.0
#             TF of sheepyards: 0.0
#             TF-IDF of polyxenos: 0.0
#             TF-IDF of balearic: 0.0
#             TF-IDF of phalanxes: 0.0
#             TF-IDF of sheepyards: 0.0
# In tlg0012.tlg002.perseus-eng3.txt:
#             TF of polyxenos: 0.0
#             TF of balearic: 0.0
#             TF of phalanxes: 0.0
#             TF of sheepyards: 0.0
#             TF-IDF of polyxenos: 0.0
#             TF-IDF of balearic: 0.0
#             TF-IDF of phalanxes: 0.0
#             TF-IDF of sheepyards: 0.0
